# %% [markdown]
# ## Comparing All ISP Offers

# %%
import pandas as pd

# %%
# inputs
fn_xfinity = "../data/output/speed_price_xfinity.csv.gz"
fn_hughes = "../data/output/speed_price_hughes.csv.gz"
fn_viasat = "../data/output/speed_price_viasat.csv.gz"

# %%
hughes_df = pd.read_csv(fn_hughes, compression='gzip')
xfinity_df = pd.read_csv(fn_xfinity, compression='gzip')
viasat_df = pd.read_csv(fn_viasat, compression='gzip')

# %%
# columns of interest to summarize
cols  = ['speed_down','speed_up', 'speed_unit', 'price', 'technology', 'package', 'fastest_speed_down', 
        'fastest_speed_price', 'n_providers','income_dollars_below_median', 'internet_perc_broadband']

# %%
hughes_df[cols].describe()
# Out:
#        speed_down  speed_up   price  fastest_speed_down  fastest_speed_price  \
# count       700.0     700.0  700.00          700.000000           700.000000
# mean         15.0       3.0   49.99           49.928571           149.704286
# std           0.0       0.0    0.00            1.335350             5.341400
# min          15.0       3.0   49.99           25.000000            49.990000
# 25%          15.0       3.0   49.99           50.000000           149.990000
# 50%          15.0       3.0   49.99           50.000000           149.990000
# 75%          15.0       3.0   49.99           50.000000           149.990000
# max          15.0       3.0   49.99           50.000000           149.990000
#
#        n_providers  income_dollars_below_median  internet_perc_broadband
# count   609.000000                   525.000000               611.000000
# mean      2.642036                 -1210.417143                 0.831851
# std       0.522462                 36068.500551                 0.104983
# min       2.000000                -99015.000000                 0.519330
# 25%       2.000000                -25275.000000                 0.743902
# 50%       3.000000                  6477.000000                 0.846004
# 75%       3.000000                 21890.000000                 0.919028
# max       4.000000                 64499.000000                 1.000000

# %%
xfinity_df[cols].describe()
# Out:
#        speed_down  speed_up  price  fastest_speed_down  fastest_speed_price  \
# count       276.0     276.0  276.0          276.000000           276.000000
# mean        400.0      10.0  102.0         1556.521739           122.793478
# std           0.0       0.0    0.0          398.352338             6.473225
# min         400.0      10.0  102.0         1200.000000           117.000000
# 25%         400.0      10.0  102.0         1200.000000           117.000000
# 50%         400.0      10.0  102.0         1200.000000           117.000000
# 75%         400.0      10.0  102.0         2000.000000           130.000000
# max         400.0      10.0  102.0         2000.000000           130.000000
#
#        n_providers  income_dollars_below_median  internet_perc_broadband
# count   244.000000                   201.000000               244.000000
# mean      2.684426                 -4947.303483                 0.839453
# std       0.516002                 39146.903757                 0.100789
# min       2.000000                -99015.000000                 0.524570
# 25%       2.000000                -32943.000000                 0.736842
# 50%       3.000000                  5436.000000                 0.869469
# 75%       3.000000                 18631.000000                 0.924127
# max       4.000000                 64499.000000                 1.000000

# %%
viasat_df[cols].describe()
# Out:
#        speed_down         price  fastest_speed_down  fastest_speed_price  \
# count        95.0  9.500000e+01                95.0         9.500000e+01
# mean         25.0  6.999000e+01                50.0         2.999900e+02
# std           0.0  1.428624e-14                 0.0         5.714498e-14
# min          25.0  6.999000e+01                50.0         2.999900e+02
# 25%          25.0  6.999000e+01                50.0         2.999900e+02
# 50%          25.0  6.999000e+01                50.0         2.999900e+02
# 75%          25.0  6.999000e+01                50.0         2.999900e+02
# max          25.0  6.999000e+01                50.0         2.999900e+02
#
#        n_providers  income_dollars_below_median  internet_perc_broadband
# count    74.000000                    70.000000                74.000000
# mean      2.810811                  2368.871429                 0.838520
# std       0.612108                 41440.871403                 0.109826
# min       2.000000                -96429.000000                 0.545151
# 25%       2.000000                -19368.250000                 0.781324
# 50%       3.000000                  2965.000000                 0.840054
# 75%       3.000000                 42148.000000                 0.939900
# max       4.000000                 64009.000000                 1.000000

# %%
# dataframe using frequencies and x_labels from the OP
df = pd.DataFrame({'Down Speed': [15, 25, 400]}, index=['Hughes Net', 'Viasat', 'Xfinity'])


# plot
ax = df.plot(kind='bar', title='Download Speed for Cheapest Package per Provider',
             xlabel='Provider', ylabel='Speed (in mbps)', legend=False, rot=0)

# annotate
ax.bar_label(ax.containers[0], label_type='edge')

# pad the spacing between the number and the edge of the figure
ax.margins(y=0.1)

# %%
# dataframe using frequencies and x_labels from the OP
df = pd.DataFrame({'Cost': [40.99, 69.99, 102.00]}, index=['Hughes Net', 'Viasat', 'Xfinity'])

# plot
ax = df.plot(kind='bar', title='Cost for Cheapest Package per Provider',
             xlabel='Provider', ylabel='Cost (in $)', legend=False, rot=0)

# annotate
ax.bar_label(ax.containers[0], label_type='edge')

# pad the spacing between the number and the edge of the figure
ax.margins(y=0.1)
